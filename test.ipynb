# %%
import pandas as pd

# %%
cust_df = pd.read_excel('datasets/car_data.xlsx', sheet_name='Customer Data ')

# %%
cust_df
# Out:
#     Sr No            Customer name  CAR ID Customer Purchase Model Name   \
# 0        1              Ramu Singh      C1                       GLANZA
# 1        2           Anushka Tiwari    C11                 INNOVA CRYSTA
# 2        3             Ramesh Singh    C11                 INNOVA CRYSTA
# 3        4           DEVENDRA KUMAR    C11                 INNOVA CRYSTA
# 4        5          V.K Enterprises    C11                 INNOVA CRYSTA
# ..     ...                      ...    ...                           ...
# 83      85       Pramod Kumar Verma    C24                         HILUX
# 84      86  Shailendra Pratap Singh    C33                       BALENO
# 85      87        Ravi Kumar Sharma    C19               INNOVA HYCROSS
# 86      88      Sangeet Vishwakarma    C24                         HILUX
# 87      89            AJEET AWASTHI    C34                       BALENO
#
#       PRICE        VARIANTS Sales person Name  Date Of Vehicle Purchase   \
# ...

# %%
import plotly.express as px

# %%
px.bar(cust_df, cust_df.index, 'Total Accessories Sale ', log_y=True)

# %%
liv_df= pd.read_excel('datasets/car_data.xlsx', sheet_name='Data ')
liv_df
# Out:
#    Vehicle Wholesale & Retail Tracking Data                      Unnamed: 1  \
# 0                                        NaN                            NaN
# 1                                     Month   Wholesale Vehicle Model Name
# 2                        2023-01-01 00:00:00                        GLANZA
# 3                        2023-01-01 00:00:00                  INNOVA CRYSTA
# 4                        2023-01-01 00:00:00                INNOVA HYCROSS
# 5                        2023-02-01 00:00:00                         DZIRE
# 6                        2023-02-01 00:00:00                        BALENO
# 7                        2023-02-01 00:00:00                        BREEZA
# 8                        2023-02-01 00:00:00                       ALTO K10
# 9                        2023-02-01 00:00:00                         CRETA
# 10                       2023-03-01 00:00:00               GRAND I 10 NIOS
# ...

# %%
ct_df = pd.read_excel('datasets/car_data.xlsx', sheet_name='Car Details ')
ct_df
# Out:
#    Car Details  Unnamed: 1   Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 0           NaN        NaN          NaN                    NaN         NaN
# 1        Sr No      CAR ID  Brand Name             Model Name   Fuel Type
# 2             1         C1     Toyotya                 GLANZA       Petrol
# 3             2         C2     Toyotya                 GLANZA       Petrol
# 4             3         C3     Toyotya                 GLANZA       Petrol
# 5             4         C4     Toyotya                 GLANZA       Petrol
# 6             5         C5     Toyotya   URBAN CRUISER HYRYDER     Petrol
# 7             6         C6     Toyotya   URBAN CRUISER HYRYDER     Petrol
# 8             7         C7     Toyotya   URBAN CRUISER HYRYDER     Petrol
# 9             8         C8     Toyotya   URBAN CRUISER HYRYDER     Petrol
# 10            9         C9     Toyotya   URBAN CRUISER HYRYDER     Petrol
# 11           10        C10     Toyotya           INNOVA CRYSTA      DIESEL
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns',None)

# %%
df1 = pd.read_excel('datasets/car_data.xlsx',skiprows=2)
df2 = pd.read_excel('datasets/car_data.xlsx',sheet_name=2,skiprows=0)
df1.set_index('CAR ID', inplace=True)
df2.set_index('CAR ID', inplace=True)

# %%
df = df1.join(df2, how='left', rsuffix='_Customer')
df
# Out:
#         Sr No  Brand Name             Model Name  Fuel Type   \
# CAR ID
# C1           1    Toyotya                 GLANZA      Petrol
# C10         10    Toyotya           INNOVA CRYSTA     DIESEL
# C11         11    Toyotya           INNOVA CRYSTA     DIESEL
# C11         11    Toyotya           INNOVA CRYSTA     DIESEL
# C11         11    Toyotya           INNOVA CRYSTA     DIESEL
# ...        ...         ...                    ...        ...
# C8           8    Toyotya   URBAN CRUISER HYRYDER    Petrol
# C9           9    Toyotya   URBAN CRUISER HYRYDER    Petrol
# C9           9    Toyotya   URBAN CRUISER HYRYDER    Petrol
# C9           9    Toyotya   URBAN CRUISER HYRYDER    Petrol
# C9           9    Toyotya   URBAN CRUISER HYRYDER    Petrol
#
#        Engine Capacity - No. of cylinders OR FUEL TANK CAPACITY      Varient   \
# CAR ID
# C1                                            4 Cylinders                  E
# ...
